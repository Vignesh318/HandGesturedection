# %%
import cv2
from gesture_classifier import GestureClassifier
from gesture_logger import GestureLogger
from hand_detector import HandDetector


cap = cv2.VideoCapture(0)

detector = HandDetector()
classifier = GestureClassifier()
logger = GestureLogger()

last_gesture = None

while True:
    success, img = cap.read()
    if not success:
        break

    img = detector.find_hands(img)
    lm_list = detector.find_positions(img)

    gesture, count = classifier.classify(lm_list)

    if gesture:
        cv2.putText(img, f"Gesture: {gesture}", (20, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)

        cv2.putText(img, f"Fingers: {count}", (20, 90),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)

        if gesture != last_gesture:
            logger.log(gesture)
            last_gesture = gesture

    cv2.imshow("Hand Gesture Recognition", img)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       4 from hand_detector import HandDetector
#       7 cap = cv2.VideoCapture(0)
# ----> 9 detector = HandDetector()
#      10 classifier = GestureClassifier()
#      11 logger = GestureLogger()
#
# File D:\msc_project\jupyterlab\handgesture\hand_detector.py:11, in HandDetector.__init__(self)
#      10 def __init__(self):
# ---> 11     self.mp_hands = mp.solutions.hands
#      12     self.hands = self.mp_hands.Hands(
#      13         static_image_mode=False,
#      14         max_num_hands=1,
#      15         min_detection_confidence=0.7,
#      16         min_tracking_confidence=0.7
#      17     )
#      18     self.mp_draw = mp.solutions.drawing_utils
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
import os
print(os.listdir())
import mediapipe as mp

print(mp)
print(mp.__file__)
print(dir(mp))
import mediapipe as mp
print(mp.__version__)
# Out:
# ['.ipynb_checkpoints', 'gesture_classifier.ipynb', 'gesture_classifier.py', 'gesture_logger.ipynb', 'gesture_logger.py', 'hand_detector.ipynb', 'hand_detector.py', 'main.ipynb', 'README.md', 'requirements.txt', 'Untitled.ipynb', '__pycache__']
# <module 'mediapipe' from 'C:\\Users\\vnd31\\AppData\\Local\\Python\\pythoncore-3.14-64\\Lib\\site-packages\\mediapipe\\__init__.py'>
# C:\Users\vnd31\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\mediapipe\__init__.py
# ['Image', 'ImageFormat', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'tasks']
# 0.10.35

# %%
import sys
print(sys.version)

import mediapipe as mp
print(mp.__file__)
print(mp.__version__)
print(hasattr(mp, "solutions"))
# Out:
# 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# C:\Users\vnd31\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\mediapipe\__init__.py
# 0.10.35
# False
